# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#base_url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weaterh_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = # YOUR CODE HERE
    url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    weather = requests.get(url).json()
    try:
#         # Parse the JSON and retrieve data
#         city_weather = # YOUR CODE HERE
#         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
#         city_lat = # YOUR CODE HERE
#         city_lng = # YOUR CODE HERE
#         city_max_temp = # YOUR CODE HERE
#         city_humidity = # YOUR CODE HERE
#         city_clouds = # YOUR CODE HERE
#         city_wind = # YOUR CODE HERE
#         city_country = # YOUR CODE HERE
#         city_date = # YOUR CODE HERE

#         # Append the City information into city_data list
         city_data.append({"City": city, 
                            "Lat": weather["coord"]["lat"], 
                            "Lng": weather["coord"]["lon"], 
                            "Max Temp": weather["main"]["temp_max"],
                            "Humidity": weather["main"]["humidity"],
                            "Cloudiness": weather["clouds"]["all"],
                            "Wind Speed": weather["wind"]["speed"],
                            "Country": weather["sys"]["country"],
                            "Date": time.ctime(weather['dt'])})

     # If an error is experienced, skip the city
    except:
         print("City not found. Skipping...")       
    pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iwanai
# Processing Record 2 of Set 1 | el bauga
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | sosnovka
# Processing Record 6 of Set 1 | sparti
# Processing Record 7 of Set 1 | udachny
# Processing Record 8 of Set 1 | invercargill
# Processing Record 9 of Set 1 | abbeville
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | fale old settlement
# Processing Record 12 of Set 1 | puerto natales
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | piacabucu
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | razdol'noye
# Processing Record 18 of Set 1 | fangshan
# Processing Record 19 of Set 1 | burao
# Processing Record 20 of Set 1 | plainview
# Processing Record 21 of Set 1 | port-aux-francais
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | kununurra
# Processing Record 25 of Set 1 | arpacay
# Processing Record 26 of Set 1 | vikulovo
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | margaret river
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | mao
# Processing Record 32 of Set 1 | blackmans bay
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | sathupalli
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | hassi messaoud
# Processing Record 37 of Set 1 | manatutu
# City not found. Skipping...
# Processing Record 38 of Set 1 | sharm el-sheikh
# Processing Record 39 of Set 1 | saint-pierre
# Processing Record 40 of Set 1 | polyarnyy
# Processing Record 41 of Set 1 | atafu village
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | harsin
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | grytviken
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | talnakh
# Processing Record 50 of Set 1 | usogorsk
# Processing Record 0 of Set 2 | mount gambier
# Processing Record 1 of Set 2 | soure
# Processing Record 2 of Set 2 | ilhabela
# Processing Record 3 of Set 2 | susuman
# Processing Record 4 of Set 2 | pangai
# Processing Record 5 of Set 2 | bam
# Processing Record 6 of Set 2 | namtsy
# Processing Record 7 of Set 2 | serov
# Processing Record 8 of Set 2 | ataq
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | choibalsan
# Processing Record 11 of Set 2 | hamilton
# Processing Record 12 of Set 2 | aasiaat
# Processing Record 13 of Set 2 | aykhal
# Processing Record 14 of Set 2 | show low
# Processing Record 15 of Set 2 | el calafate
# Processing Record 16 of Set 2 | wailua homesteads
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | abraham's bay
# City not found. Skipping...
# Processing Record 19 of Set 2 | dudinka
# Processing Record 20 of Set 2 | bardai
# Processing Record 21 of Set 2 | dalnerechensk
# Processing Record 22 of Set 2 | sijunjung
# Processing Record 23 of Set 2 | queenstown
# Processing Record 24 of Set 2 | hargeysa
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | al lagowa
# Processing Record 27 of Set 2 | hami
# Processing Record 28 of Set 2 | hawaiian paradise park
# Processing Record 29 of Set 2 | st. john's
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | barra de santo antonio
# Processing Record 32 of Set 2 | chernyshevskiy
# Processing Record 33 of Set 2 | west island
# Processing Record 34 of Set 2 | sibi
# Processing Record 35 of Set 2 | antalaha
# Processing Record 36 of Set 2 | lisakovsk
# Processing Record 37 of Set 2 | ongjin
# Processing Record 38 of Set 2 | le vauclin
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 2 | ribeira brava
# Processing Record 42 of Set 2 | kilosa
# Processing Record 43 of Set 2 | newman
# Processing Record 44 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | papatowai
# Processing Record 47 of Set 2 | port mathurin
# Processing Record 48 of Set 2 | tvoroyri
# Processing Record 49 of Set 2 | mallammaduri
# Processing Record 0 of Set 3 | flying fish cove
# Processing Record 1 of Set 3 | sarangani
# Processing Record 2 of Set 3 | murun-kuren
# Processing Record 3 of Set 3 | chui
# Processing Record 4 of Set 3 | nadi
# Processing Record 5 of Set 3 | nabire
# Processing Record 6 of Set 3 | acapulco de juarez
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | enewetak
# Processing Record 9 of Set 3 | takoradi
# Processing Record 10 of Set 3 | matoury
# Processing Record 11 of Set 3 | laminusa
# Processing Record 12 of Set 3 | langxiang
# Processing Record 13 of Set 3 | edinburgh of the seven seas
# Processing Record 14 of Set 3 | al jawf
# Processing Record 15 of Set 3 | conception bay south
# Processing Record 16 of Set 3 | svetlyy
# Processing Record 17 of Set 3 | tra mhor
# Processing Record 18 of Set 3 | alo
# Processing Record 19 of Set 3 | isafjordur
# Processing Record 20 of Set 3 | yamada
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | tazacorte
# Processing Record 23 of Set 3 | lihue
# Processing Record 24 of Set 3 | constantia
# Processing Record 25 of Set 3 | turtas
# Processing Record 26 of Set 3 | labytnangi
# Processing Record 27 of Set 3 | corner brook
# Processing Record 28 of Set 3 | shangri-la
# City not found. Skipping...
# Processing Record 29 of Set 3 | stanley
# Processing Record 30 of Set 3 | malango
# Processing Record 31 of Set 3 | vilyuysk
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | mugia
# Processing Record 35 of Set 3 | rawson
# Processing Record 36 of Set 3 | port douglas
# Processing Record 37 of Set 3 | kaga bandoro
# Processing Record 38 of Set 3 | alice springs
# Processing Record 39 of Set 3 | klyuchi
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | remire-montjoly
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | lerwick
# Processing Record 44 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 3 | keflavik
# Processing Record 46 of Set 3 | morehead city
# Processing Record 47 of Set 3 | anadyr
# Processing Record 48 of Set 3 | roccella ionica
# Processing Record 49 of Set 3 | ciudad acuna
# Processing Record 0 of Set 4 | bamboo flat
# Processing Record 1 of Set 4 | college
# Processing Record 2 of Set 4 | hammerfest
# Processing Record 3 of Set 4 | dalbandin
# Processing Record 4 of Set 4 | quiberon
# Processing Record 5 of Set 4 | robore
# Processing Record 6 of Set 4 | ruteng
# Processing Record 7 of Set 4 | nagqu
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | vorgashor
# Processing Record 10 of Set 4 | kerikeri
# Processing Record 11 of Set 4 | greymouth
# Processing Record 12 of Set 4 | berdigestyakh
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | horasan
# Processing Record 15 of Set 4 | olgii
# City not found. Skipping...
# Processing Record 16 of Set 4 | itamaraca
# Processing Record 17 of Set 4 | rocky mount
# Processing Record 18 of Set 4 | nova sintra
# Processing Record 19 of Set 4 | wainwright
# Processing Record 20 of Set 4 | caruthersville
# Processing Record 21 of Set 4 | utrik
# Processing Record 22 of Set 4 | launceston
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | jamestown
# Processing Record 25 of Set 4 | ta`u
# Processing Record 26 of Set 4 | marabba
# Processing Record 27 of Set 4 | tolanaro
# Processing Record 28 of Set 4 | mpika
# Processing Record 29 of Set 4 | bolkhov
# Processing Record 30 of Set 4 | bangui
# Processing Record 31 of Set 4 | faya-largeau
# Processing Record 32 of Set 4 | gulf shores
# Processing Record 33 of Set 4 | sainte-anne-des-monts
# Processing Record 34 of Set 4 | mermoz boabab
# Processing Record 35 of Set 4 | inari
# Processing Record 36 of Set 4 | roxas
# Processing Record 37 of Set 4 | laojunmiao
# Processing Record 38 of Set 4 | hovd
# Processing Record 39 of Set 4 | trevelin
# Processing Record 40 of Set 4 | crane
# Processing Record 41 of Set 4 | almeirim
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | limbazi
# Processing Record 44 of Set 4 | egilsstadir
# Processing Record 45 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 46 of Set 4 | temiskaming shores
# Processing Record 47 of Set 4 | myaydo
# Processing Record 48 of Set 4 | gaoping
# Processing Record 49 of Set 4 | camana
# Processing Record 0 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 1 of Set 5 | qamdo
# Processing Record 2 of Set 5 | dapa
# Processing Record 3 of Set 5 | trincomalee
# Processing Record 4 of Set 5 | qaqortoq
# Processing Record 5 of Set 5 | bilibino
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | nova xavantina
# Processing Record 8 of Set 5 | selfoss
# Processing Record 9 of Set 5 | sault ste. marie
# Processing Record 10 of Set 5 | minas de marcona
# Processing Record 11 of Set 5 | ouani
# Processing Record 12 of Set 5 | knittelfeld
# Processing Record 13 of Set 5 | plastun
# Processing Record 14 of Set 5 | nehe
# Processing Record 15 of Set 5 | gilgit
# Processing Record 16 of Set 5 | flin flon
# Processing Record 17 of Set 5 | usinsk
# Processing Record 18 of Set 5 | obudu
# Processing Record 19 of Set 5 | cabedelo
# Processing Record 20 of Set 5 | sola
# Processing Record 21 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | magadan
# Processing Record 24 of Set 5 | man
# Processing Record 25 of Set 5 | ketchikan
# Processing Record 26 of Set 5 | ar rutbah
# Processing Record 27 of Set 5 | kailua-kona
# Processing Record 28 of Set 5 | kapa'a
# Processing Record 29 of Set 5 | uturoa
# Processing Record 30 of Set 5 | tromso
# Processing Record 31 of Set 5 | hope
# Processing Record 32 of Set 5 | taman rajawali
# City not found. Skipping...
# Processing Record 33 of Set 5 | igarka
# Processing Record 34 of Set 5 | tanza
# Processing Record 35 of Set 5 | nykobing falster
# Processing Record 36 of Set 5 | as sulayyil
# Processing Record 37 of Set 5 | la passe
# Processing Record 38 of Set 5 | banda aceh
# Processing Record 39 of Set 5 | wanning
# Processing Record 40 of Set 5 | shengli
# Processing Record 41 of Set 5 | coronel oviedo
# Processing Record 42 of Set 5 | bol
# Processing Record 43 of Set 5 | arkhara
# Processing Record 44 of Set 5 | alofi
# Processing Record 45 of Set 5 | baruun-urt
# Processing Record 46 of Set 5 | fontanelas
# Processing Record 47 of Set 5 | petauke
# Processing Record 48 of Set 5 | fort st. john
# Processing Record 49 of Set 5 | qusmuryn
# Processing Record 0 of Set 6 | gemena
# Processing Record 1 of Set 6 | castillos
# Processing Record 2 of Set 6 | khandyga
# Processing Record 3 of Set 6 | moab
# Processing Record 4 of Set 6 | along
# Processing Record 5 of Set 6 | puerto colombia
# Processing Record 6 of Set 6 | silvi
# Processing Record 7 of Set 6 | shakawe
# Processing Record 8 of Set 6 | kyzylorda
# Processing Record 9 of Set 6 | vadso
# Processing Record 10 of Set 6 | antsiranana
# Processing Record 11 of Set 6 | papao
# Processing Record 12 of Set 6 | waliso
# Processing Record 13 of Set 6 | khash
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | lib
# Processing Record 16 of Set 6 | asten
# Processing Record 17 of Set 6 | st. catharines
# Processing Record 18 of Set 6 | natal
# Processing Record 19 of Set 6 | badger
# Processing Record 20 of Set 6 | daru
# Processing Record 21 of Set 6 | maloye ganyushkino
# Processing Record 22 of Set 6 | tondano
# Processing Record 23 of Set 6 | puerto baquerizo moreno
# Processing Record 24 of Set 6 | taltal
# Processing Record 25 of Set 6 | monahans
# Processing Record 26 of Set 6 | nar'yan-mar
# Processing Record 27 of Set 6 | moscow
# Processing Record 28 of Set 6 | pirajui
# Processing Record 29 of Set 6 | smithers
# Processing Record 30 of Set 6 | kimbe
# Processing Record 31 of Set 6 | camiri
# Processing Record 32 of Set 6 | homer
# Processing Record 33 of Set 6 | xilin hot
# Processing Record 34 of Set 6 | charters towers
# Processing Record 35 of Set 6 | yuxi
# Processing Record 36 of Set 6 | howrah
# Processing Record 37 of Set 6 | chinde
# Processing Record 38 of Set 6 | aral
# Processing Record 39 of Set 6 | muan
# Processing Record 40 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 6 | mawlaik
# Processing Record 42 of Set 6 | ust-nera
# Processing Record 43 of Set 6 | castanos
# Processing Record 44 of Set 6 | champerico
# Processing Record 45 of Set 6 | ende
# Processing Record 46 of Set 6 | oranjemund
# Processing Record 47 of Set 6 | revda
# Processing Record 48 of Set 6 | saldanha
# Processing Record 49 of Set 6 | colonia
# Processing Record 0 of Set 7 | sligo
# Processing Record 1 of Set 7 | broome
# Processing Record 2 of Set 7 | hilo
# Processing Record 3 of Set 7 | urengoy
# Processing Record 4 of Set 7 | mejit
# Processing Record 5 of Set 7 | saipan
# Processing Record 6 of Set 7 | hantsavichy
# Processing Record 7 of Set 7 | weno
# Processing Record 8 of Set 7 | koryazhma
# Processing Record 9 of Set 7 | moquegua
# Processing Record 10 of Set 7 | kalemie
# Processing Record 11 of Set 7 | maragogi
# Processing Record 12 of Set 7 | agat village
# Processing Record 13 of Set 7 | singapore
# Processing Record 14 of Set 7 | xai-xai
# Processing Record 15 of Set 7 | sal rei
# Processing Record 16 of Set 7 | east ballina
# Processing Record 17 of Set 7 | san juan
# Processing Record 18 of Set 7 | chonchi
# Processing Record 19 of Set 7 | dryden
# Processing Record 20 of Set 7 | clinton
# Processing Record 21 of Set 7 | sretensk
# Processing Record 22 of Set 7 | mountain home
# Processing Record 23 of Set 7 | zhezqazghan
# Processing Record 24 of Set 7 | i-n-salah
# Processing Record 25 of Set 7 | zouerate
# Processing Record 26 of Set 7 | danielskuil
# Processing Record 27 of Set 7 | marsh harbour
# Processing Record 28 of Set 7 | luuq
# Processing Record 29 of Set 7 | freeport
# Processing Record 30 of Set 7 | at taj
# Processing Record 31 of Set 7 | carmo do rio claro
# Processing Record 32 of Set 7 | nuku'alofa
# Processing Record 33 of Set 7 | tralee
# Processing Record 34 of Set 7 | palompon
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | ivanovskoye
# Processing Record 37 of Set 7 | odacho-oda
# Processing Record 38 of Set 7 | korla
# Processing Record 39 of Set 7 | mantua
# Processing Record 40 of Set 7 | kingston
# Processing Record 41 of Set 7 | recani
# Processing Record 42 of Set 7 | asau village
# City not found. Skipping...
# Processing Record 43 of Set 7 | tommot
# Processing Record 44 of Set 7 | sabi
# Processing Record 45 of Set 7 | lubang
# Processing Record 46 of Set 7 | porto velho
# Processing Record 47 of Set 7 | miles city
# Processing Record 48 of Set 7 | maintirano
# Processing Record 49 of Set 7 | ulaangom
# Processing Record 0 of Set 8 | mount pearl
# Processing Record 1 of Set 8 | ubinskoye
# Processing Record 2 of Set 8 | broken hill
# Processing Record 3 of Set 8 | klaksvik
# Processing Record 4 of Set 8 | camocim
# Processing Record 5 of Set 8 | crescent city
# Processing Record 6 of Set 8 | tocopilla
# Processing Record 7 of Set 8 | whitehorse
# Processing Record 8 of Set 8 | fantanele
# Processing Record 9 of Set 8 | merizo village
# Processing Record 10 of Set 8 | kronoby
# Processing Record 11 of Set 8 | tekirova
# Processing Record 12 of Set 8 | humahuaca
# Processing Record 13 of Set 8 | katsuura
# Processing Record 14 of Set 8 | ouadda
# Processing Record 15 of Set 8 | buka
# Processing Record 16 of Set 8 | fukuecho
# Processing Record 17 of Set 8 | acarau
# Processing Record 18 of Set 8 | macusani
# Processing Record 19 of Set 8 | phan rang-thap cham
# Processing Record 20 of Set 8 | montrose
# Processing Record 21 of Set 8 | saint-philippe
# Processing Record 22 of Set 8 | marivan
# Processing Record 23 of Set 8 | iskateley
# Processing Record 24 of Set 8 | vilyuchinsk
# Processing Record 25 of Set 8 | tazovsky
# Processing Record 26 of Set 8 | belle fourche
# Processing Record 27 of Set 8 | qulsary
# Processing Record 28 of Set 8 | port augusta
# Processing Record 29 of Set 8 | hotan
# Processing Record 30 of Set 8 | ljusdal
# Processing Record 31 of Set 8 | lae
# Processing Record 32 of Set 8 | qandala
# Processing Record 33 of Set 8 | sisimiut
# Processing Record 34 of Set 8 | ypsonas
# Processing Record 35 of Set 8 | nuuk
# Processing Record 36 of Set 8 | mata-utu
# Processing Record 37 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 8 | sicuani
# Processing Record 39 of Set 8 | saint-francois
# Processing Record 40 of Set 8 | dul'durga
# Processing Record 41 of Set 8 | mount isa
# Processing Record 42 of Set 8 | aparri
# Processing Record 43 of Set 8 | khunti
# Processing Record 44 of Set 8 | quellon
# Processing Record 45 of Set 8 | kegen
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | laguna
# Processing Record 48 of Set 8 | churapcha
# Processing Record 49 of Set 8 | priargunsk
# Processing Record 0 of Set 9 | ed damer
# Processing Record 1 of Set 9 | waingapu
# Processing Record 2 of Set 9 | ouanaminthe
# Processing Record 3 of Set 9 | murray bridge
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | kiruna
# Processing Record 6 of Set 9 | mulayjah
# Processing Record 7 of Set 9 | mbanza-ngungu
# Processing Record 8 of Set 9 | el granada
# Processing Record 9 of Set 9 | toliara
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | ponta delgada
# Processing Record 12 of Set 9 | debark'
# Processing Record 13 of Set 9 | ola
# Processing Record 14 of Set 9 | san antonio de pale
# Processing Record 15 of Set 9 | gizo
# Processing Record 16 of Set 9 | tarawa
# Processing Record 17 of Set 9 | mahina
# Processing Record 18 of Set 9 | itaituba
# Processing Record 19 of Set 9 | dubbo
# Processing Record 20 of Set 9 | devils lake
# Processing Record 21 of Set 9 | impfondo
# Processing Record 22 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 9 | karratha
# Processing Record 24 of Set 9 | garissa
# Processing Record 25 of Set 9 | hasaki
# Processing Record 26 of Set 9 | weihai
# Processing Record 27 of Set 9 | lakatoro
# Processing Record 28 of Set 9 | birao
# Processing Record 29 of Set 9 | kardonikskaya
# Processing Record 30 of Set 9 | smolensk
# Processing Record 31 of Set 9 | cruz
# Processing Record 32 of Set 9 | sur
# Processing Record 33 of Set 9 | guarapari
# Processing Record 34 of Set 9 | tottori
# Processing Record 35 of Set 9 | tual
# Processing Record 36 of Set 9 | ambon
# Processing Record 37 of Set 9 | arkhangel'sk
# Processing Record 38 of Set 9 | sinabang
# Processing Record 39 of Set 9 | fuxin
# Processing Record 40 of Set 9 | berdyansk
# Processing Record 41 of Set 9 | cable beach
# City not found. Skipping...
# Processing Record 42 of Set 9 | yorkton
# Processing Record 43 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 44 of Set 9 | lock haven
# Processing Record 45 of Set 9 | quang ngai
# Processing Record 46 of Set 9 | ojinaga
# Processing Record 47 of Set 9 | barra do garcas
# Processing Record 48 of Set 9 | tosontsengel
# Processing Record 49 of Set 9 | kassala
# Processing Record 0 of Set 10 | tumaco
# Processing Record 1 of Set 10 | ostroleka
# Processing Record 2 of Set 10 | nelson bay
# Processing Record 3 of Set 10 | massaguet
# Processing Record 4 of Set 10 | volchikha
# Processing Record 5 of Set 10 | ellwood city
# Processing Record 6 of Set 10 | kabansk
# Processing Record 7 of Set 10 | emerald
# Processing Record 8 of Set 10 | soio
# Processing Record 9 of Set 10 | san juan nepomuceno
# Processing Record 10 of Set 10 | villa dolores
# Processing Record 11 of Set 10 | la'ie
# Processing Record 12 of Set 10 | cidade velha
# Processing Record 13 of Set 10 | hultsfred
# Processing Record 14 of Set 10 | sidi ifni
# Processing Record 15 of Set 10 | ijuw
# City not found. Skipping...
# Processing Record 16 of Set 10 | brokopondo
# Processing Record 17 of Set 10 | sungailiat
# Processing Record 18 of Set 10 | mahenge
# Processing Record 19 of Set 10 | richards bay
# Processing Record 20 of Set 10 | mek'ele
# Processing Record 21 of Set 10 | walvis bay
# Processing Record 22 of Set 10 | dakhla
# Processing Record 23 of Set 10 | zermatt
# Processing Record 24 of Set 10 | vyazemskiy
# Processing Record 25 of Set 10 | smirnykh
# Processing Record 26 of Set 10 | kindu
# Processing Record 27 of Set 10 | kamloops
# Processing Record 28 of Set 10 | nadym
# Processing Record 29 of Set 10 | kharan
# Processing Record 30 of Set 10 | ar raqqah
# Processing Record 31 of Set 10 | chibougamau
# Processing Record 32 of Set 10 | grande prairie
# Processing Record 33 of Set 10 | bad bruckenau
# Processing Record 34 of Set 10 | bargara
# City not found. Skipping...
# Processing Record 35 of Set 10 | osakarovka
# Processing Record 36 of Set 10 | ondjiva
# Processing Record 37 of Set 10 | kone
# Processing Record 38 of Set 10 | arkalyk
# Processing Record 39 of Set 10 | tsiombe
# Processing Record 40 of Set 10 | san miguel
# Processing Record 41 of Set 10 | hoa binh
# Processing Record 42 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 10 | bikenibeu village
# Processing Record 44 of Set 10 | santana
# Processing Record 45 of Set 10 | loreto
# Processing Record 46 of Set 10 | awjilah
# Processing Record 47 of Set 10 | uvira
# Processing Record 48 of Set 10 | bocas del toro
# Processing Record 49 of Set 10 | rikaze
# Processing Record 0 of Set 11 | pangody
# Processing Record 1 of Set 11 | bandon
# Processing Record 2 of Set 11 | nansio
# Processing Record 3 of Set 11 | plouzane
# Processing Record 4 of Set 11 | jawf al maqbabah
# Processing Record 5 of Set 11 | suva
# Processing Record 6 of Set 11 | coquimbo
# Processing Record 7 of Set 11 | cuito
# Processing Record 8 of Set 11 | debre werk'
# Processing Record 9 of Set 11 | akureyri
# Processing Record 10 of Set 11 | dharmavaram
# Processing Record 11 of Set 11 | tari
# Processing Record 12 of Set 11 | jodhpur
# Processing Record 13 of Set 11 | bubaque
# Processing Record 14 of Set 11 | praia da vitoria
# Processing Record 15 of Set 11 | codo
# Processing Record 16 of Set 11 | candolim
# Processing Record 17 of Set 11 | whakatane
# Processing Record 18 of Set 11 | buta
# Processing Record 19 of Set 11 | kitale
# Processing Record 20 of Set 11 | kapuskasing
# Processing Record 21 of Set 11 | shingu
# Processing Record 22 of Set 11 | randers
# Processing Record 23 of Set 11 | miches
# Processing Record 24 of Set 11 | puerto ayacucho
# Processing Record 25 of Set 11 | nushki
# Processing Record 26 of Set 11 | grootfontein
# Processing Record 27 of Set 11 | buri
# Processing Record 28 of Set 11 | vallenar
# Processing Record 29 of Set 11 | santiago de veraguas
# Processing Record 30 of Set 11 | saint-joseph
# Processing Record 31 of Set 11 | kaoma
# Processing Record 32 of Set 11 | huautla de jimenez
# Processing Record 33 of Set 11 | hiriyur
# Processing Record 34 of Set 11 | kozhevnikovo
# Processing Record 35 of Set 11 | aioun
# Processing Record 36 of Set 11 | sassandra
# Processing Record 37 of Set 11 | kill devil hills
# Processing Record 38 of Set 11 | afaahiti
# Processing Record 39 of Set 11 | kamina
# Processing Record 40 of Set 11 | banikoara
# Processing Record 41 of Set 11 | kavaratti
# Processing Record 42 of Set 11 | tongliao
# Processing Record 43 of Set 11 | kerman
# Processing Record 44 of Set 11 | colesberg
# Processing Record 45 of Set 11 | ikryanoye
# Processing Record 46 of Set 11 | callao
# Processing Record 47 of Set 11 | souillac
# Processing Record 48 of Set 11 | mitu
# Processing Record 49 of Set 11 | barranca
# Processing Record 0 of Set 12 | manismata
# Processing Record 1 of Set 12 | rio branco
# Processing Record 2 of Set 12 | morden
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | eilat
# Processing Record 5 of Set 12 | namibe
# Processing Record 6 of Set 12 | taco pozo
# Processing Record 7 of Set 12 | yulinshi
# Processing Record 8 of Set 12 | okha
# Processing Record 9 of Set 12 | san pedro pochutla
# Processing Record 10 of Set 12 | las terrenas
# Processing Record 11 of Set 12 | xinzhi
# Processing Record 12 of Set 12 | san sebastian de la gomera
# Processing Record 13 of Set 12 | young
# Processing Record 14 of Set 12 | twin falls
# Processing Record 15 of Set 12 | deming
# Processing Record 16 of Set 12 | genhe
# Processing Record 17 of Set 12 | srinivaspur
# Processing Record 18 of Set 12 | severo-yeniseyskiy
# Processing Record 19 of Set 12 | skeldon
# Processing Record 20 of Set 12 | buala
# Processing Record 21 of Set 12 | brookings
# Processing Record 22 of Set 12 | avare
# Processing Record 23 of Set 12 | poninka
# Processing Record 24 of Set 12 | guskhara
# Processing Record 25 of Set 12 | glace bay
# Processing Record 26 of Set 12 | bechar
# Processing Record 27 of Set 12 | bena
# Processing Record 28 of Set 12 | sao gabriel da cachoeira
# Processing Record 29 of Set 12 | mala vyska
# Processing Record 30 of Set 12 | zhicheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       iwanai  42.9744  140.5089     70.99        92           4        4.41
# 1     el bauga  18.2620   33.9081     97.95        24          23        5.66
# 2  olonkinbyen  70.9221   -8.7187     44.83        99         100        5.19
# 3    adamstown -25.0660 -130.1015     65.61        51          11       19.42
# 4     sosnovka  56.2550   51.2842     62.26        66           2        1.28
#
#   Country                      Date
# 0      JP  Fri Aug 11 15:55:25 2023
# 1      SD  Fri Aug 11 15:55:25 2023
# 2      SJ  Fri Aug 11 15:55:26 2023
# 3      PN  Fri Aug 11 15:55:26 2023
# 4      RU  Fri Aug 11 15:55:27 2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iwanai  42.9744  140.5089     70.99        92           4
# 1           el bauga  18.2620   33.9081     97.95        24          23
# 2        olonkinbyen  70.9221   -8.7187     44.83        99         100
# 3          adamstown -25.0660 -130.1015     65.61        51          11
# 4           sosnovka  56.2550   51.2842     62.26        66           2
#
#          Wind Speed Country                      Date
# City_ID
# 0              4.41      JP  Fri Aug 11 15:55:25 2023
# 1              5.66      SD  Fri Aug 11 15:55:25 2023
# 2              5.19      SJ  Fri Aug 11 15:55:26 2023
# 3             19.42      PN  Fri Aug 11 15:55:26 2023
# 4              1.28      RU  Fri Aug 11 15:55:27 2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df.Lat, city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df.Lat, city_data_df["Humidity"])

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df.Lat, city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Cloudiness ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df.Lat, city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Wind Speed ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_funct(x_values, y_values, x_label, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    return rvalue 
    plt.show()

# %%
lin_funct(city_data_df.Lat, city_data_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# -0.09367290631358255

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df.Lat>=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iwanai  42.9744  140.5089     70.99        92           4
# 1           el bauga  18.2620   33.9081     97.95        24          23
# 2        olonkinbyen  70.9221   -8.7187     44.83        99         100
# 4           sosnovka  56.2550   51.2842     62.26        66           2
# 5             sparti  37.0733   22.4297     70.95        70          90
#
#          Wind Speed Country                      Date
# City_ID
# 0              4.41      JP  Fri Aug 11 15:55:25 2023
# 1              5.66      SD  Fri Aug 11 15:55:25 2023
# 2              5.19      SJ  Fri Aug 11 15:55:26 2023
# 4              1.28      RU  Fri Aug 11 15:55:27 2023
# 5              1.43      GR  Fri Aug 11 15:55:27 2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df.Lat<=0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                  adamstown -25.0660 -130.1015     65.61        51
# 7               invercargill -46.4000  168.3500     40.01        91
# 9                   waitangi -43.9535 -176.5597     53.82        95
# 10       fale old settlement  -9.3852 -171.2468     82.49        67
# 11            puerto natales -51.7236  -72.4875     35.92        77
#
#          Cloudiness  Wind Speed Country                      Date
# City_ID
# 3                11       19.42      PN  Fri Aug 11 15:55:26 2023
# 7               100        1.01      NZ  Fri Aug 11 15:55:28 2023
# 9                99        5.01      NZ  Fri Aug 11 15:55:28 2023
# 10               20       13.09      TK  Fri Aug 11 15:55:28 2023
# 11                4        6.85      CL  Fri Aug 11 15:55:29 2023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_funct(northern_hemi_df.Lat, northern_hemi_df["Max Temp"], "Latitude", "Temperature")
# Out:
# -0.6372082728403465

# %%
# Linear regression on Southern Hemisphere
lin_funct(southern_hemi_df.Lat, southern_hemi_df["Max Temp"], "Latitude", "Temperature")
# Out:
# 0.77464836805404

# %% [markdown]
# **Discussion about the linear relationship:** As you can see with the linear regression plots as you approach the equator the temperature rises and as you get further from the equator it gets colder (has a lower temperature).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_funct(northern_hemi_df.Lat, northern_hemi_df["Humidity"], "Latitude", "Humidity")
# Out:
# 0.034320912934352896

# %%
# Southern Hemisphere
lin_funct(southern_hemi_df.Lat, southern_hemi_df["Humidity"], "Latitude", "Humidity")
# Out:
# -0.013522524285061902

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_funct(northern_hemi_df.Lat, northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness")
# Out:
# -0.09972838511552318

# %%
# Southern Hemisphere
lin_funct(southern_hemi_df.Lat, southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness")
# Out:
# -0.08832285911050981

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_funct(northern_hemi_df.Lat, northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# -0.03526143307273231

# %%
# Southern Hemisphere
lin_funct(southern_hemi_df.Lat, southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# 0.0009206355320745984

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
